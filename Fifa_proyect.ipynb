# %%
import pandas as pd
import numpy as np

# %%
import kaggle
kaggle.api.authenticate()

# %%
#kaggle datasets download -d stefanoleone992/fifa-22-complete-player-dataset

# %%
#kaggle.api.dataset_download_file('stefanoleone992/fifa-22-complete-player-dataset',file_name='players_22.csv',path='data/')

# %%
df15=pd.read_csv('data/players_15.csv')
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (104) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df15.columns.to_list()
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking_awareness',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'goalkeeping_speed',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'gk',
#  'player_face_url',
#  'club_logo_url',
#  'club_flag_url',
#  'nation_logo_url',
#  'nation_flag_url']

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(17), int64(43), object(50)
# memory usage: 13.6+ MB

# %%
df16=pd.read_csv('data/players_16.csv')

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15623 entries, 0 to 15622
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(17), int64(43), object(50)
# memory usage: 13.1+ MB

# %%
df17=pd.read_csv('data/players_17.csv')
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17596 entries, 0 to 17595
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 14.8+ MB

# %%
df18=pd.read_csv('data/players_18.csv')
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 15.1+ MB
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (81,82,83,84,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df19=pd.read_csv('data/players_19.csv')
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18085 entries, 0 to 18084
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 15.2+ MB

# %%
df20=pd.read_csv('data/players_20.csv')
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18483 entries, 0 to 18482
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 15.5+ MB

# %%
df21=pd.read_csv('data/players_21.csv')
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 15.9+ MB

# %%
df22=pd.read_csv('data/players_22.csv')
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 16.1+ MB
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#bucle para añadir columna version en todos los datasets
for i,df in zip(range(2015,2023),(df15,df16,df17,df18,df19,df20,df21,df22)):
    df['año_version']=i

# %%
#fusiono todos los datasets en uno
frames = [df15,df16,df17,df18,df19,df20,df21,df22]
df = pd.concat(frames)

# %%
#test con messi
df[df['sofifa_id']==158023]
# Out:
#    sofifa_id                                         player_url short_name  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
#
#                         long_name player_positions  overall  potential  \
# 0  Lionel Andrés Messi Cuccittini               CF       93         95
# 0  Lionel Andrés Messi Cuccittini           RW, CF       94         95
# 1  Lionel Andrés Messi Cuccittini               RW       93         93
# 1  Lionel Andrés Messi Cuccittini               RW       93         93
# 1  Lionel Andrés Messi Cuccittini       CF, RW, ST       94         94
# 0  Lionel Andrés Messi Cuccittini       RW, CF, ST       94         94
# 0  Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93
# 0  Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93
#
#      value_eur  wage_eur  age  ...    cb   rcb    rb    gk  \
# 0  100500000.0  550000.0   27  ...  45+3  45+3  54+3  15+3
# 0  111000000.0  550000.0   28  ...  44+3  44+3  57+3  19+3
# 1   89000000.0  575000.0   29  ...  45+4  45+4  57+4  19+4
# 1  105000000.0  575000.0   30  ...  45+4  45+4  57+4  19+4
# 1  110500000.0  575000.0   31  ...  48+7  48+7  59+7  19+7
# 0   95500000.0  560000.0   32  ...  53+6  53+6  63+6  19+6
# 0  103500000.0  560000.0   33  ...  52+3  52+3  62+3  19+3
# 0   78000000.0  320000.0   34  ...  50+3  50+3  61+3  19+3
#
#                                      player_face_url  \
# 0  https://cdn.sofifa.net/players/158/023/15_120.png
# 0  https://cdn.sofifa.net/players/158/023/16_120.png
# 1  https://cdn.sofifa.net/players/158/023/17_120.png
# 1  https://cdn.sofifa.net/players/158/023/18_120.png
# 1  https://cdn.sofifa.net/players/158/023/19_120.png
# 0  https://cdn.sofifa.net/players/158/023/20_120.png
# 0  https://cdn.sofifa.net/players/158/023/21_120.png
# 0  https://cdn.sofifa.net/players/158/023/22_120.png
#
#                              club_logo_url  \
# 0  https://cdn.sofifa.net/teams/241/60.png
# 0  https://cdn.sofifa.net/teams/241/60.png
# 1  https://cdn.sofifa.net/teams/241/60.png
# 1  https://cdn.sofifa.net/teams/241/60.png
# 1  https://cdn.sofifa.net/teams/241/60.png
# 0  https://cdn.sofifa.net/teams/241/60.png
# 0  https://cdn.sofifa.net/teams/241/60.png
# 0   https://cdn.sofifa.net/teams/73/60.png
#
#                          club_flag_url  \
# 0  https://cdn.sofifa.net/flags/es.png
# 0  https://cdn.sofifa.net/flags/es.png
# 1  https://cdn.sofifa.net/flags/es.png
# 1  https://cdn.sofifa.net/flags/es.png
# 1  https://cdn.sofifa.net/flags/es.png
# 0  https://cdn.sofifa.net/flags/es.png
# 0  https://cdn.sofifa.net/flags/es.png
# 0  https://cdn.sofifa.net/flags/fr.png
#
#                             nation_logo_url  \
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1369/60.png
# 1  https://cdn.sofifa.net/teams/1369/60.png
# 0                                       NaN
# 0  https://cdn.sofifa.net/teams/1369/60.png
# 0  https://cdn.sofifa.net/teams/1369/60.png
#
#                        nation_flag_url año_version
# 0  https://cdn.sofifa.net/flags/ar.png        2015
# 0  https://cdn.sofifa.net/flags/ar.png        2016
# 1  https://cdn.sofifa.net/flags/ar.png        2017
# 1  https://cdn.sofifa.net/flags/ar.png        2018
# 1  https://cdn.sofifa.net/flags/ar.png        2019
# 0  https://cdn.sofifa.net/flags/ar.png        2020
# 0  https://cdn.sofifa.net/flags/ar.png        2021
# 0  https://cdn.sofifa.net/flags/ar.png        2022
#
# [8 rows x 111 columns]

# %%
#el inicial
value=df[(df['sofifa_id']==158023)&(df['año_version']==2016)]['overall'][0]

# %%
#el anterior al inicial
value_ant=df[(df['sofifa_id']==158023)&(df['año_version']==2015)]['overall'][0]

# %%
progresion=(value-value_ant)/value_ant

# %%
progresion
# Out:
# 0.010752688172043012

# %%
#falta hacer función y aplicarla a cada fila: si sale error poner nulo y eliminarla del dataset

# %%
#primera aparición
firstfifa=df[df['sofifa_id']==158023].nsmallest(1, 'año_version')['año_version'][0]

# %%
#última aparición
lastfifa=df[df['sofifa_id']==158023].nlargest(1, 'año_version')['año_version'][0]

# %%
df[(df['sofifa_id']==158023)&(df['año_version']==2017)]
# Out:
#    sofifa_id                                         player_url short_name  \
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
#
#                         long_name player_positions  overall  potential  \
# 1  Lionel Andrés Messi Cuccittini               RW       93         93
#
#     value_eur  wage_eur  age  ...    cb   rcb    rb    gk  \
# 1  89000000.0  575000.0   29  ...  45+4  45+4  57+4  19+4
#
#                                      player_face_url  \
# 1  https://cdn.sofifa.net/players/158/023/17_120.png
#
#                              club_logo_url  \
# 1  https://cdn.sofifa.net/teams/241/60.png
#
#                          club_flag_url  \
# 1  https://cdn.sofifa.net/flags/es.png
#
#                             nation_logo_url  \
# 1  https://cdn.sofifa.net/teams/1369/60.png
#
#                        nation_flag_url año_version
# 1  https://cdn.sofifa.net/flags/ar.png        2017
#
# [1 rows x 111 columns]

# %%
print(df[(df['sofifa_id']==158023)&(df['año_version']==2017)]['overall'].to_list()[0])
# Out:
# 93

# %%
for i in range(firstfifa,lastfifa):
    print(i)
# Out:
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
for i in range(firstfifa,lastfifa):
    value_fut=df[(df['sofifa_id']==158023)&(df['año_version']==(i+1))]['overall'].to_list()[0]
    value_act=df[(df['sofifa_id']==158023)&(df['año_version']==i)]['overall'].to_list()[0]
    print(i)
    print((value_fut-value_act)/value_act)
# Out:
# 2015
# 0.010752688172043012
# 2016
# -0.010638297872340425
# 2017
# 0.0
# 2018
# 0.010752688172043012
# 2019
# 0.0
# 2020
# -0.010638297872340425
# 2021
# 0.0

# %%
def progresion_anual(row):
    #Calcula primero la primera y ultima version en que apareció el jugador en el juego. 
    #Despúes calcula la progresión porcentual que tendrá el overall en la versión siguiente.
    #El dateframe debe llamarse 'df'
    #Ojo! calculando por el dataframe segmento de la primera división tarda en ejecucarse unos 28.1s. El df total son 13 min
    #Sample Input: df.iloc[8].squeeze()
    #Sample Output: -0.022727272727272728
    
    
    firstfifa=df[df['sofifa_id']==row['sofifa_id']].nsmallest(1, 'año_version')['año_version'].to_list()[0]
    lastfifa=df[df['sofifa_id']==row['sofifa_id']].nlargest(1, 'año_version')['año_version'].to_list()[0]
    try:
        if row['año_version'] in range(firstfifa,lastfifa):
            value_fut=df[(df['sofifa_id']==row['sofifa_id'])&(df['año_version']==(row['año_version']+1))]['overall'].to_list()[0]
            value_act=df[(df['sofifa_id']==row['sofifa_id'])&(df['año_version']==row['año_version'])]['overall'].to_list()[0]
            return (value_fut-value_act)/value_act
        else:
            return None
    except:
        pass

# %%
# %%time
df['progresion_anual']=df.apply(progresion_anual, axis=1)
# Out:
# Wall time: 12min 51s

# %%
df.groupby(['long_name','año_version'])['progresion_anual'].max().nlargest(10)
# Out:
# long_name                      año_version
# Mahmut Ertuğrul Taşkıran       2015           0.674419
# Jorge Andrés Carrascal Guardo  2016           0.500000
# Bartłomiej Drągowski           2015           0.420000
# Tanguy Ndombèlé Alvaro         2017           0.411765
# Giovani Lo Celso               2016           0.396226
# Kevin Linford Stewart          2016           0.384615
# Mikel Oyarzabal Ugarte         2016           0.375000
# Íñigo Lekue Martínez           2015           0.372549
# Leonardo Sequeira              2018           0.365385
# Majed Al Khaibary              2015           0.361702
# Name: progresion_anual, dtype: float64

# %%
#ejemplo Haaland
df[df['sofifa_id']==239085]
# Out:
#        sofifa_id                                         player_url  \
# 15867     239085  https://sofifa.com/player/239085/erling-haland...
# 8565      239085  https://sofifa.com/player/239085/erling-braut-...
# 3265      239085  https://sofifa.com/player/239085/erling-braut-...
# 139       239085  https://sofifa.com/player/239085/erling-haalan...
# 29        239085  https://sofifa.com/player/239085/erling-haalan...
#
#        short_name             long_name player_positions  overall  potential  \
# 15867   E. Håland  Erling Braut Haaland               ST       58         78
# 8565   E. Haaland  Erling Braut Haaland               ST       67         84
# 3265    E. Håland   Erling Braut Håland               ST       73         85
# 139    E. Haaland  Erling Braut Haaland               ST       84         92
# 29     E. Haaland  Erling Braut Haaland               ST       88         93
#
#          value_eur  wage_eur  age  ...   rcb    rb    gk  \
# 15867     250000.0    1000.0   16  ...  35+1  36+1  15+1
# 8565     1500000.0    2000.0   17  ...  47+1  45+1  16+1
# 3265     6500000.0   12000.0   18  ...  51+2  51+2  17+2
# 139     92000000.0   56000.0   19  ...  57+2  57+2  18+2
# 29     137500000.0  110000.0   20  ...  60+3  60+3  19+3
#
#                                          player_face_url  \
# 15867  https://cdn.sofifa.net/players/239/085/18_120.png
# 8565   https://cdn.sofifa.net/players/239/085/19_120.png
# 3265   https://cdn.sofifa.net/players/239/085/20_120.png
# 139    https://cdn.sofifa.net/players/239/085/21_120.png
# 29     https://cdn.sofifa.net/players/239/085/22_120.png
#
#                                  club_logo_url  \
# 15867  https://cdn.sofifa.net/teams/417/60.png
# 8565   https://cdn.sofifa.net/teams/417/60.png
# 3265   https://cdn.sofifa.net/teams/191/60.png
# 139     https://cdn.sofifa.net/teams/22/60.png
# 29      https://cdn.sofifa.net/teams/22/60.png
#
#                              club_flag_url  \
# 15867  https://cdn.sofifa.net/flags/no.png
# 8565   https://cdn.sofifa.net/flags/no.png
# 3265   https://cdn.sofifa.net/flags/at.png
# 139    https://cdn.sofifa.net/flags/de.png
# 29     https://cdn.sofifa.net/flags/de.png
#
#                                 nation_logo_url  \
# 15867                                       NaN
# 8565                                        NaN
# 3265                                        NaN
# 139    https://cdn.sofifa.net/teams/1352/60.png
# 29     https://cdn.sofifa.net/teams/1352/60.png
#
#                            nation_flag_url  año_version progresion_anual
# 15867  https://cdn.sofifa.net/flags/no.png         2018         0.155172
# 8565   https://cdn.sofifa.net/flags/no.png         2019         0.089552
# 3265   https://cdn.sofifa.net/flags/no.png         2020         0.150685
# 139    https://cdn.sofifa.net/flags/no.png         2021         0.047619
# 29     https://cdn.sofifa.net/flags/no.png         2022              NaN
#
# [5 rows x 112 columns]

# %%
import seaborn as sns

# %%
sns.jointplot(data=df_new, x="age", y="progresion_anual")

# %%
df.to_csv('data\players_total.csv')

# %%
df=pd.read_csv('data\players_total.csv')
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (26,109) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142079 entries, 0 to 142078
# Columns: 113 entries, Unnamed: 0 to progresion_anual
# dtypes: float64(18), int64(45), object(50)
# memory usage: 122.5+ MB

# %%
df_new['progresion_anual'].mean()
# Out:
# 0.01731646649918268

# %%
df_new['progresion_anual'].median()
# Out:
# 0.0128205128205128

# %%
#quito valores nulos de progresion anual
df=df[df['progresion_anual'].notnull()]

# %%
#data set total
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87747 entries, 0 to 122838
# Columns: 113 entries, Unnamed: 0 to progresion_anual
# dtypes: float64(18), int64(45), object(50)
# memory usage: 76.3+ MB

# %%
df_new['progresion_anual'].mean()
# Out:
# -0.005967412040968702

# %%
df[df['progresion_anual']>=0.05].count()
# Out:
# Unnamed: 0          14183
# sofifa_id           14183
# player_url          14183
# short_name          14183
# long_name           14183
#                     ...
# club_flag_url       14093
# nation_logo_url       484
# nation_flag_url     14183
# año_version         14183
# progresion_anual    14183
# Length: 113, dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43973 entries, 29 to 122838
# Columns: 113 entries, Unnamed: 0 to progresion_anual
# dtypes: float64(18), int64(45), object(50)
# memory usage: 38.2+ MB

# %%
#por debajo de la mediana (1,3% progresion anual)
43774/87747
# Out:
# 0.49886605809885237

# %%
#por encima de la mediana (1,3% progresion anual)
43973/87747
# Out:
# 0.5011339419011476

# %%
#por encima de la mediana (5% progresion anual) ==> y objetivo
14183/87747
# Out:
# 0.16163515561785588

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87747 entries, 0 to 122838
# Columns: 113 entries, Unnamed: 0 to progresion_anual
# dtypes: float64(18), int64(45), object(50)
# memory usage: 76.3+ MB

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking_awareness',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'goalkeeping_speed',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'gk',
#  'player_face_url',
#  'club_logo_url',
#  'club_flag_url',
#  'nation_logo_url',
#  'nation_flag_url',
#  'año_version',
#  'progresion_anual']

# %%
df = df[df.columns.drop(list(df.filter(regex='url')))]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87747 entries, 0 to 122838
# Columns: 107 entries, Unnamed: 0 to progresion_anual
# dtypes: float64(18), int64(45), object(44)
# memory usage: 72.3+ MB

# %%
pd.set_option('display.max_columns', None)
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'sofifa_id', 'short_name', 'long_name', 'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id', 'club_name', 'league_name', 'league_level', 'club_position', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nationality_name', 'nation_team_id', 'nation_position', 'nation_jersey_number', 'preferred_foot', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'año_version', 'progresion_anual']

# %%
df.isna().sum().sort_values(ascending=False).head(30)
# Out:
# club_loaned_from             82077
# nation_jersey_number         81070
# nation_team_id               81070
# nation_position              81070
# player_tags                  79585
# goalkeeping_speed            78114
# player_traits                45640
# release_clause_eur           39028
# mentality_composure          22682
# pace                          9633
# shooting                      9633
# passing                       9633
# dribbling                     9633
# defending                     9633
# physic                        9633
# club_joined                   6510
# league_level                  1142
# value_eur                      946
# club_contract_valid_until      840
# league_name                    840
# club_jersey_number             840
# club_position                  840
# club_name                      840
# club_team_id                   840
# wage_eur                       834
# cf                               0
# rf                               0
# Unnamed: 0                       0
# lw                               0
# lf                               0
# dtype: int64

# %%
df.drop(['club_loaned_from','nation_jersey_number','nation_position','player_tags','club_contract_valid_until','release_clause_eur','club_jersey_number','real_face'])

# %%
df['mentality_composure'].median()
# Out:
# 60.0

# %%
'''columnas a transformar:
* goalkeeping_speed (nan == 0)
* nation_team_id (0 o 1)
* player_traits (nan == 0)
* club_name (nan = jugador_libre)
* club_team_id ((nan = 0))
* club_position (cambiar a 1 (titular) 0 no titular & nan)
* league_name (nan = jugador_libre) => categorizar a partir de mejor a peor liga
* wage_eur (nan = 0)
* variables liga competitiva (overall medio)
* 

'''

# %% [markdown]
# ## Columnas a añadir al dataset (para deternimar ligas y equipos competitivos)
# * Overall medio por equipo
# * Overall medio por liga & Nª de jugadores x equipo
# * Clasificación mundial de el equipo (dataset externo)
# Ojo! overall medio por temporada

# %%
df[df.league_level.isna()]["club_name"].sort_values().head(100)
# Out:
# 91080             AEK Athens
# 92006             AEK Athens
# 88219             AEK Athens
# 91079             AEK Athens
# 90986             AEK Athens
#                 ...
# 90576    FC Lokomotiv Moscow
# 87148    FC Lokomotiv Moscow
# 90804    FC Lokomotiv Moscow
# 90883    FC Lokomotiv Moscow
# 93013    FC Lokomotiv Moscow
# Name: club_name, Length: 100, dtype: object

# %%
df[df['sofifa_id']==24438]
# Out:
#       Unnamed: 0  sofifa_id short_name                 long_name  \
# 1539        1539      24438   M. Yepes  Mario Alberto Yepes Díaz
#
#      player_positions  overall  potential  value_eur  wage_eur  age  \
# 1539               CB       73         73        NaN       NaN   38
#
#              dob  height_cm  weight_kg  club_team_id club_name league_name  \
# 1539  1976-01-13        186         83           NaN       NaN         NaN
#
#       league_level club_position  club_jersey_number club_loaned_from  \
# 1539           NaN           NaN                 NaN              NaN
#
#      club_joined  club_contract_valid_until  nationality_id nationality_name  \
# 1539         NaN                        NaN              56         Colombia
#
#       nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 1539        111109.0             LCB                   3.0           Left
#
#       weak_foot  skill_moves  international_reputation   work_rate  \
# 1539          3            2                         2  Low/Medium
#
#           body_type real_face  release_clause_eur player_tags player_traits  \
# 1539  Normal (185+)        No                 NaN         NaN  Power Header
#
#       pace  shooting  passing  dribbling  defending  physic  \
# 1539  34.0      35.0     47.0       39.0       77.0    70.0
#
#       attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 1539                  25                   27                          71
#
#       attacking_short_passing  attacking_volleys  skill_dribbling  \
# 1539                       57                 24               30
#
#       skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 1539           37                 43                  59                  50
#
#       movement_acceleration  movement_sprint_speed  movement_agility  \
# 1539                     34                     34                30
#
#       movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 1539                  64                54                59             75
#
#       power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 1539             34              84                28                    78
#
#       mentality_interceptions  mentality_positioning  mentality_vision  \
# 1539                       80                     33                47
#
#       mentality_penalties  mentality_composure  defending_marking_awareness  \
# 1539                   58                  NaN                           78
#
#       defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 1539                         78                        68                  12
#
#       goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 1539                     6                    5                       13
#
#       goalkeeping_reflexes  goalkeeping_speed  ls  st  rs  lw  lf  cf  rf  rw  \
# 1539                    13                NaN  43  43  43  38  43  43  43  38
#
#      lam cam ram  lm lcm  cm rcm  rm lwb ldm cdm rdm rwb  lb lcb  cb rcb  rb  \
# 1539  44  44  44  42  52  52  52  42  56  65  65  65  56  63  73  73  73  63
#
#       gk  año_version  progresion_anual
# 1539  14         2015          0.013699

# %%
df[df['club_name'].isnull()]
# Out:
#         Unnamed: 0  sofifa_id     short_name                        long_name  \
# 406            406      20209  Ricardo Costa  Ricardo Miguel Moreira da Costa
# 476            476     178416        J. Lens           Jeremain Marciano Lens
# 1054          1054     189060    A. Dragović              Aleksandar Dragović
# 1539          1539      24438       M. Yepes         Mario Alberto Yepes Díaz
# 1637          1637     163488   D. Limberský                  David Limberský
# ...            ...        ...            ...                              ...
# 116666       12770     253090       M. Lukov                     Martin Lukov
# 116668       12772     253170      A. Szalai                    Attila Szalai
# 118379       14483     254136        E. Just                Elijah Henry Just
# 118742       14846     231063       C. Lewis               Clayton Rhys Lewis
# 120498       16602     258500     F. Krastev            Filip Yavorov Krastev
#
#        player_positions  overall  potential  value_eur  wage_eur  age  \
# 406              CB, RB       78         78        NaN       NaN   33
# 476              RW, ST       78         80        NaN       NaN   26
# 1054            CB, CDM       75         81        NaN       NaN   23
# 1539                 CB       73         73        NaN       NaN   38
# 1637             LB, RB       73         73        NaN       NaN   30
# ...                 ...      ...        ...        ...       ...  ...
# 116666               GK       63         66        NaN       NaN   26
# 116668               CB       63         76        NaN       NaN   22
# 118379      LW, RW, CAM       61         75        NaN       NaN   20
# 118742      CAM, CM, LM       60         68        NaN       NaN   23
# 120498          CAM, CM       58         75        NaN       NaN   18
#
#                dob  height_cm  weight_kg  club_team_id club_name league_name  \
# 406     1981-05-16        183         80           NaN       NaN         NaN
# 476     1987-11-24        178         73           NaN       NaN         NaN
# 1054    1991-03-06        186         79           NaN       NaN         NaN
# 1539    1976-01-13        186         83           NaN       NaN         NaN
# 1637    1983-10-06        178         73           NaN       NaN         NaN
# ...            ...        ...        ...           ...       ...         ...
# 116666  1993-07-05        188         83           NaN       NaN         NaN
# 116668  1998-01-20        192         83           NaN       NaN         NaN
# 118379  2000-05-01        174         69           NaN       NaN         NaN
# 118742  1997-02-12        173         72           NaN       NaN         NaN
# 120498  2001-10-15        172         63           NaN       NaN         NaN
#
#         league_level club_position  club_jersey_number club_loaned_from  \
# 406              NaN           NaN                 NaN              NaN
# 476              NaN           NaN                 NaN              NaN
# 1054             NaN           NaN                 NaN              NaN
# 1539             NaN           NaN                 NaN              NaN
# 1637             NaN           NaN                 NaN              NaN
# ...              ...           ...                 ...              ...
# 116666           NaN           NaN                 NaN              NaN
# 116668           NaN           NaN                 NaN              NaN
# 118379           NaN           NaN                 NaN              NaN
# 118742           NaN           NaN                 NaN              NaN
# 120498           NaN           NaN                 NaN              NaN
#
#        club_joined  club_contract_valid_until  nationality_id  \
# 406            NaN                        NaN              38
# 476            NaN                        NaN              34
# 1054           NaN                        NaN               4
# 1539           NaN                        NaN              56
# 1637           NaN                        NaN              12
# ...            ...                        ...             ...
# 116666         NaN                        NaN               9
# 116668         NaN                        NaN              23
# 118379         NaN                        NaN             198
# 118742         NaN                        NaN             198
# 120498         NaN                        NaN               9
#
#        nationality_name  nation_team_id nation_position  nation_jersey_number  \
# 406            Portugal          1354.0             SUB                  13.0
# 476         Netherlands        105035.0             SUB                  17.0
# 1054            Austria          1322.0             RCB                   3.0
# 1539           Colombia        111109.0             LCB                   3.0
# 1637     Czech Republic          1330.0              LB                   8.0
# ...                 ...             ...             ...                   ...
# 116666         Bulgaria          1327.0             SUB                  23.0
# 116668          Hungary          1886.0              RB                   4.0
# 118379      New Zealand        111473.0             SUB                  22.0
# 118742      New Zealand        111473.0             SUB                   8.0
# 120498         Bulgaria          1327.0             SUB                  21.0
#
#        preferred_foot  weak_foot  skill_moves  international_reputation  \
# 406             Right          3            2                         2
# 476             Right          4            4                         2
# 1054            Right          4            2                         2
# 1539             Left          3            2                         2
# 1637            Right          4            3                         2
# ...               ...        ...          ...                       ...
# 116666          Right          3            1                         1
# 116668          Right          4            2                         1
# 118379          Right          4            2                         1
# 118742           Left          3            2                         1
# 120498          Right          3            2                         1
#
#             work_rate         body_type real_face  release_clause_eur  \
# 406        Low/Medium  Stocky (170-185)       Yes                 NaN
# 476        Medium/Low  Normal (170-185)        No                 NaN
# 1054    Medium/Medium     Normal (185+)        No                 NaN
# 1539       Low/Medium     Normal (185+)        No                 NaN
# 1637      High/Medium  Normal (170-185)        No                 NaN
# ...               ...               ...       ...                 ...
# 116666  Medium/Medium     Normal (185+)        No                 NaN
# 116668    Medium/High     Normal (185+)        No                 NaN
# 118379       High/Low    Lean (170-185)        No                 NaN
# 118742  Medium/Medium  Normal (170-185)        No                 NaN
# 120498     Medium/Low    Lean (170-185)        No                 NaN
#
#        player_tags                                      player_traits  pace  \
# 406            NaN                            Dives Into Tackles (AI)  54.0
# 476            NaN  Beat Offside Trap, Speed Dribbler (AI), Chip S...  86.0
# 1054           NaN                                                NaN  72.0
# 1539           NaN                                       Power Header  34.0
# 1637           NaN                               Long Shot Taker (AI)  83.0
# ...            ...                                                ...   ...
# 116666         NaN                                                NaN   NaN
# 116668         NaN                                                NaN  62.0
# 118379         NaN                                                NaN  70.0
# 118742         NaN                                                NaN  70.0
# 120498         NaN                                                NaN  65.0
#
#         shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 406         37.0     44.0       52.0       77.0    83.0                  40
# 476         75.0     70.0       81.0       31.0    71.0                  75
# 1054        50.0     61.0       64.0       77.0    77.0                  48
# 1539        35.0     47.0       39.0       77.0    70.0                  25
# 1637        62.0     68.0       69.0       71.0    80.0                  78
# ...          ...      ...        ...        ...     ...                 ...
# 116666       NaN      NaN        NaN        NaN     NaN                  14
# 116668      29.0     51.0       31.0       63.0    67.0                  63
# 118379      53.0     53.0       69.0       27.0    45.0                  51
# 118742      54.0     58.0       64.0       44.0    51.0                  51
# 120498      46.0     60.0       59.0       37.0    41.0                  53
#
#         attacking_finishing  attacking_heading_accuracy  \
# 406                      24                          87
# 476                      75                          62
# 1054                     40                          75
# 1539                     27                          71
# 1637                     51                          58
# ...                     ...                         ...
# 116666                    9                          11
# 116668                   26                          72
# 118379                   57                          40
# 118742                   52                          42
# 120498                   48                          25
#
#         attacking_short_passing  attacking_volleys  skill_dribbling  \
# 406                          52                 34               47
# 476                          74                 86               82
# 1054                         67                 36               61
# 1539                         57                 24               30
# 1637                         61                 63               68
# ...                         ...                ...              ...
# 116666                       21                  5                5
# 116668                       57                 24               22
# 118379                       57                 51               71
# 118742                       62                 51               62
# 120498                       63                 52               58
#
#         skill_curve  skill_fk_accuracy  skill_long_passing  \
# 406              24                 27                  46
# 476              70                 64                  50
# 1054             31                 60                  61
# 1539             37                 43                  59
# 1637             62                 70                  69
# ...             ...                ...                 ...
# 116666           13                 11                  19
# 116668           18                 19                  61
# 118379           45                 38                  53
# 118742           60                 64                  57
# 120498           57                 58                  60
#
#         skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 406                     54                     52                     55
# 476                     79                     84                     88
# 1054                    67                     70                     73
# 1539                    50                     34                     34
# 1637                    73                     81                     85
# ...                    ...                    ...                    ...
# 116666                  11                     25                     31
# 116668                  34                     55                     68
# 118379                  65                     74                     67
# 118742                  62                     73                     67
# 120498                  59                     67                     63
#
#         movement_agility  movement_reactions  movement_balance  \
# 406                   58                  71                65
# 476                   78                  82                82
# 1054                  67                  73                64
# 1539                  30                  64                54
# 1637                  62                  68                78
# ...                  ...                 ...               ...
# 116666                32                  57                34
# 116668                44                  59                44
# 118379                71                  59                84
# 118742                76                  55                81
# 120498                73                  49                53
#
#         power_shot_power  power_jumping  power_stamina  power_strength  \
# 406                   69             90             74              85
# 476                   79             75             74              76
# 1054                  68             80             73              82
# 1539                  59             75             34              84
# 1637                  75             68             78              81
# ...                  ...            ...            ...             ...
# 116666                49             49             25              61
# 116668                28             73             58              70
# 118379                51             53             56              45
# 118742                57             55             54              49
# 120498                43             37             56              31
#
#         power_long_shots  mentality_aggression  mentality_interceptions  \
# 406                   31                    89                       77
# 476                   74                    52                       22
# 1054                  52                    67                       83
# 1539                  28                    78                       80
# 1637                  71                    81                       75
# ...                  ...                   ...                      ...
# 116666                 9                    20                       19
# 116668                33                    68                       64
# 118379                47                    28                       19
# 118742                56                    49                       49
# 120498                46                    48                       42
#
#         mentality_positioning  mentality_vision  mentality_penalties  \
# 406                        55                44                   39
# 476                        68                72                   66
# 1054                       66                70                   54
# 1539                       33                47                   58
# 1637                       67                72                   66
# ...                       ...               ...                  ...
# 116666                     14                38                   19
# 116668                     37                37                   46
# 118379                     54                56                   54
# 118742                     53                58                   58
# 120498                     49                62                   21
#
#         mentality_composure  defending_marking_awareness  \
# 406                     NaN                           75
# 476                     NaN                           21
# 1054                    NaN                           75
# 1539                    NaN                           78
# 1637                    NaN                           70
# ...                     ...                          ...
# 116666                 22.0                           16
# 116668                 46.0                           60
# 118379                 64.0                           24
# 118742                 56.0                           45
# 120498                 41.0                           39
#
#         defending_standing_tackle  defending_sliding_tackle  \
# 406                            74                        85
# 476                            38                        31
# 1054                           78                        74
# 1539                           78                        68
# 1637                           74                        73
# ...                           ...                       ...
# 116666                         13                        14
# 116668                         65                        59
# 118379                         30                        27
# 118742                         42                        39
# 120498                         36                        38
#
#         goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 406                     13                    14                    6
# 476                     15                    15                   13
# 1054                     9                     6                   10
# 1539                    12                     6                    5
# 1637                     5                     7                   12
# ...                    ...                   ...                  ...
# 116666                  65                    63                   65
# 116668                  10                    14                    9
# 118379                  13                     9                   10
# 118742                  15                    12                   11
# 120498                  11                    14                   13
#
#         goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 406                           7                    12                NaN
# 476                          14                     5                NaN
# 1054                         12                     7                NaN
# 1539                         13                    13                NaN
# 1637                         14                    11                NaN
# ...                         ...                   ...                ...
# 116666                       63                    59               28.0
# 116668                       10                    12                NaN
# 118379                       15                    12                NaN
# 118742                        6                    13                NaN
# 120498                       12                     7                NaN
#
#           ls    st    rs  lw  lf  cf  rf  rw   lam   cam   ram    lm   lcm  \
# 406       53    53    53  49  52  52  52  49    51    51    51    52    55
# 476       76    76    76  78  76  76  76  78    76    76    76    75    66
# 1054      61    61    61  62  63  63  63  62    65    65    65    64    68
# 1539      43    43    43  38  43  43  43  38    44    44    44    42    52
# 1637      66    66    66  71  68  68  68  71    68    68    68    71    70
# ...      ...   ...   ...  ..  ..  ..  ..  ..   ...   ...   ...   ...   ...
# 116666  22+2  22+2  22+2  19  21  21  21  19  21+2  21+2  21+2  20+2  22+2
# 116668  43+2  43+2  43+2  42  40  40  40  42  41+2  41+2  41+2  45+2  47+2
# 118379  56+2  56+2  56+2  61  60  60  60  61  60+2  60+2  60+2  61+2  55+2
# 118742  56+2  56+2  56+2  60  59  59  59  60  60+2  60+2  60+2  59+2  57+2
# 120498  49+2  49+2  49+2  57  55  55  55  57  58+2  58+2  58+2  57+2  56+2
#
#           cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 406       55    55    52    65    65    65    65    65    71    78    78
# 476       66    66    75    58    56    56    56    58    52    48    48
# 1054      68    68    64    70    72    72    72    70    72    75    75
# 1539      52    52    42    56    65    65    65    56    63    73    73
# 1637      70    70    71    72    72    72    72    72    73    72    72
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 116666  22+2  22+2  20+2  21+2  23+2  23+2  23+2  21+2  21+2  23+2  23+2
# 116668  47+2  47+2  45+2  57+2  58+2  58+2  58+2  57+2  60+2  63+2  63+2
# 118379  55+2  55+2  61+2  46+2  42+2  42+2  42+2  46+2  44+2  35+2  35+2
# 118742  57+2  57+2  59+2  53+2  52+2  52+2  52+2  53+2  52+2  48+2  48+2
# 120498  56+2  56+2  57+2  51+2  49+2  49+2  49+2  51+2  48+2  40+2  40+2
#
#          rcb    rb    gk  año_version  progresion_anual
# 406       78    71    15         2015         -0.025641
# 476       48    52    17         2015          0.012821
# 1054      75    72    12         2015          0.040000
# 1539      73    63    14         2015          0.013699
# 1637      72    73    13         2015          0.027397
# ...      ...   ...   ...          ...               ...
# 116666  23+2  21+2  62+2         2021          0.031746
# 116668  63+2  60+2  17+2         2021          0.190476
# 118379  35+2  44+2  17+2         2021          0.049180
# 118742  48+2  52+2  16+2         2021          0.066667
# 120498  40+2  48+2  15+2         2021          0.017241
#
# [840 rows x 107 columns]

# %%
df.groupby(['league_name','año_version'])['club_team_id'].nunique()
# Out:
# league_name                  año_version
# Argentina Primera División   2015           20
#                              2016           30
#                              2017           30
#                              2018           28
#                              2019           26
#                                             ..
# Ukrainian Premier League     2018            1
#                              2019            2
#                              2021            2
# Uruguayan Primera División   2021            6
# Venezuelan Primera División  2021            5
# Name: club_team_id, Length: 287, dtype: int64
